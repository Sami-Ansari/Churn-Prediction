# %%
import pandas as pd
import numpy as np

# %%
# Ignore warnings

import warnings
# Set the warning filter to ignore FutureWarning
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.drop(columns="customerID" , inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df = df.infer_objects()

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df["tenure"].unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39], dtype=int64)

# %%
df[df["TotalCharges"].str.contains(" ")]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df = df.loc[~df['TotalCharges'].str.contains(' ')]

# %%
df['TotalCharges'] = df['TotalCharges'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 22

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
for i in df:
  print(f"Value counts of {i} column")
  print(df[i].value_counts(), '\n')
# Out:
# Value counts of gender column
# gender
# Male      3549
# Female    3483
# Name: count, dtype: int64
#
# Value counts of SeniorCitizen column
# SeniorCitizen
# 0    5890
# 1    1142
# Name: count, dtype: int64
#
# Value counts of Partner column
# Partner
# No     3639
# Yes    3393
# Name: count, dtype: int64
#
# Value counts of Dependents column
# Dependents
# No     4933
# Yes    2099
# Name: count, dtype: int64
#
# Value counts of tenure column
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 38     59
# 28     57
# 39     56
# 44     51
# 36     50
# Name: count, Length: 72, dtype: int64
#
# Value counts of PhoneService column
# PhoneService
# Yes    6352
# No      680
# Name: count, dtype: int64
#
# Value counts of MultipleLines column
# MultipleLines
# No                  3385
# Yes                 2967
# No phone service     680
# Name: count, dtype: int64
#
# Value counts of InternetService column
# InternetService
# Fiber optic    3096
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df, hue = 'Churn')
plt.show()
# Out:
# c:\Users\samia\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.FacetGrid(df, col='Churn', row='InternetService')

g.map(plt.hist, 'tenure')
g.add_legend()
plt.show()
# Out:
# c:\Users\samia\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'SeniorCitizen'}>,
#         <Axes: title={'center': 'tenure'}>],
#        [<Axes: title={'center': 'MonthlyCharges'}>,
#         <Axes: title={'center': 'TotalCharges'}>]], dtype=object)

# %%
def create_histograms(df, features):
    for feature in features:
        plt.figure(figsize=(5, 3))
        sns.histplot(data = df, x = feature, hue = 'Churn', multiple = 'dodge', bins=30)
        plt.title(f'Histogram of {feature} with Churn')
        plt.xlabel(feature)
        plt.ylabel('Frequency')

# %%
features = ["gender","Partner","Dependents","SeniorCitizen"]
create_histograms(df, features)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
columns_to_convert = ['gender','Partner', 'Dependents', 'PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','InternetService','Contract','PaymentMethod'] 
# Encode labels in column 'Age'.
for i in columns_to_convert:
    df.loc[:,i]= label_encoder.fit_transform(df[i])
 
# df['Age'].unique()

# %%
df
# Out:
#      gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0         0              0       1          0       1            0
# 1         1              0       0          0      34            1
# 2         1              0       0          0       2            1
# 3         1              0       0          0      45            0
# 4         0              0       0          0       2            1
# ...     ...            ...     ...        ...     ...          ...
# 7038      1              0       1          1      24            1
# 7039      0              0       1          1      72            1
# 7040      0              0       1          1      11            0
# 7041      1              1       1          0       4            1
# 7042      1              0       0          0      66            1
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0                1               0              0            2
# ...

# %%
# columns_to_convert = ['Partner', 'Dependents', 'PhoneService','MultipleLines','OnlineSecurity']  # Replace with your column names

# for column in columns_to_convert:
#     df.loc[df[column] == "Yes", column] = 1
#     df.loc[df[column] == "No", column] = 0
#     df.loc[df[column] == "No phone service", column] = 2

# %%
df["OnlineBackup"].value_counts()
# Out:
# OnlineBackup
# 0    3087
# 2    2425
# 1    1520
# Name: count, dtype: int64

# %%
y = df["Churn"]
X = df.drop(columns="Churn")
corr = df.copy()
corr["Churn"]= label_encoder.fit_transform(df["Churn"])

# %%
plt.figure(figsize=(8,8))
sns.displot(df['MonthlyCharges'],kde = True)
plt.show()
# Out:
# c:\Users\samia\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="MonthlyCharges", y="PaperlessBilling", col="InternetService", hue="InternetService", style="InternetService",kind="line", data=df) # scatter can be used instead of "line" plot
plt.show()
# Out:
# c:\Users\samia\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(8,8))
sns.relplot(x="tenure", y="MonthlyCharges",col="Churn", hue="Churn", style="Churn",kind="scatter", data=df)
plt.show()
# Out:
# c:\Users\samia\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
Q1 = X.quantile(0.25)
Q3 = X.quantile(0.75)
IQR  = Q3 - Q1
print(IQR)
# Out:
# gender                    1.0
# SeniorCitizen             0.0
# Partner                   1.0
# Dependents                1.0
# tenure                   46.0
# PhoneService              0.0
# MultipleLines             2.0
# InternetService           1.0
# OnlineSecurity            2.0
# OnlineBackup              2.0
# DeviceProtection          2.0
# TechSupport               2.0
# StreamingTV               2.0
# StreamingMovies           2.0
# Contract                  1.0
# PaperlessBilling          1.0
# PaymentMethod             1.0
# MonthlyCharges         54.275
# TotalCharges        3393.2875
# dtype: object

# %%
sns.set (rc = {'figure.figsize':(20, 10)})
sns.heatmap(corr.corr(),cmap="YlGnBu",annot=True)
# Out:
# <Axes: >

# %%
X.drop(columns="InternetService",inplace=True)
X.drop(columns="PhoneService",inplace=True)
X.drop(columns="MultipleLines",inplace=True)
X.drop(columns="StreamingTV",inplace=True)
X.drop(columns="StreamingMovies",inplace=True)

# %%
X
# Out:
#      gender  SeniorCitizen Partner Dependents  tenure OnlineSecurity  \
# 0         0              0       1          0       1              0
# 1         1              0       0          0      34              2
# 2         1              0       0          0       2              2
# 3         1              0       0          0      45              2
# 4         0              0       0          0       2              0
# ...     ...            ...     ...        ...     ...            ...
# 7038      1              0       1          1      24              2
# 7039      0              0       1          1      72              0
# 7040      0              0       1          1      11              2
# 7041      1              1       1          0       4              0
# 7042      1              0       0          0      66              2
#
#      OnlineBackup DeviceProtection TechSupport Contract PaperlessBilling  \
# ...

# %%
df.drop(columns="InternetService",inplace=True)
df.drop(columns="PhoneService",inplace=True)
df.drop(columns="MultipleLines",inplace=True)
df.drop(columns="StreamingTV",inplace=True)
df.drop(columns="StreamingMovies",inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
numerical = ['tenure','MonthlyCharges','TotalCharges']
df[numerical]
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0          1           29.85         29.85
# 1         34           56.95       1889.50
# 2          2           53.85        108.15
# 3         45           42.30       1840.75
# 4          2           70.70        151.65
# ...      ...             ...           ...
# 7038      24           84.80       1990.50
# 7039      72          103.20       7362.90
# 7040      11           29.60        346.45
# 7041       4           74.40        306.60
# 7042      66          105.65       6844.50
#
# [7032 rows x 3 columns]

# %%
df[numerical] = scaler.fit_transform(df[numerical])
df[numerical]
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 0     0.000000        0.115423      0.001275
# 1     0.464789        0.385075      0.215867
# 2     0.014085        0.354229      0.010310
# 3     0.619718        0.239303      0.210241
# 4     0.014085        0.521891      0.015330
# ...        ...             ...           ...
# 7038  0.323944        0.662189      0.227521
# 7039  1.000000        0.845274      0.847461
# 7040  0.140845        0.112935      0.037809
# 7041  0.042254        0.558706      0.033210
# 7042  0.915493        0.869652      0.787641
#
# [7032 rows x 3 columns]

# %%
df
# Out:
#      gender  SeniorCitizen Partner Dependents    tenure OnlineSecurity  \
# 0         0              0       1          0  0.000000              0
# 1         1              0       0          0  0.464789              2
# 2         1              0       0          0  0.014085              2
# 3         1              0       0          0  0.619718              2
# 4         0              0       0          0  0.014085              0
# ...     ...            ...     ...        ...       ...            ...
# 7038      1              0       1          1  0.323944              2
# 7039      0              0       1          1  1.000000              0
# 7040      0              0       1          1  0.140845              2
# 7041      1              1       1          0  0.042254              0
# 7042      1              0       0          0  0.915493              2
#
#      OnlineBackup DeviceProtection TechSupport Contract PaperlessBilling  \
# ...

# %%
x1 = df.drop(columns="Churn")

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

X_std = std.fit_transform(X)

# %%
print(X_std)
# Out:
# [[-1.00943013 -0.44032709  1.03561683 ...  0.39980518 -1.16169394
#   -0.99419409]
#  [ 0.99065797 -0.44032709 -0.9656081  ...  1.33663626 -0.26087792
#   -0.17373982]
#  [ 0.99065797 -0.44032709 -0.9656081  ...  1.33663626 -0.36392329
#   -0.95964911]
#  ...
#  [-1.00943013 -0.44032709  1.03561683 ...  0.39980518 -1.17000405
#   -0.85451414]
#  [ 0.99065797  2.27103902  1.03561683 ...  1.33663626  0.31916782
#   -0.87209546]
#  [ 0.99065797 -0.44032709 -0.9656081  ... -1.47385696  1.35793167
#    2.01234407]]

# %%
from sklearn.model_selection import train_test_split 

X_train,X_test,Y_train,Y_test = train_test_split(X_std,y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
# array([[-1.00943013, -0.44032709, -0.9656081 , ..., -1.47385696,
#         -0.52347742, -0.09137012],
#        [ 0.99065797, -0.44032709, -0.9656081 , ..., -0.53702589,
#         -0.37888149, -0.92411146],
#        [-1.00943013, -0.44032709,  1.03561683, ...,  0.39980518,
#          0.4305233 ,  0.95951636],
#        ...,
#        [ 0.99065797, -0.44032709, -0.9656081 , ...,  0.39980518,
#          0.54354081, -0.66127403],
#        [-1.00943013, -0.44032709, -0.9656081 , ..., -1.47385696,
#         -1.49742241, -0.57100707],
#        [ 0.99065797,  2.27103902,  1.03561683, ...,  0.39980518,
#          0.29423748, -0.36168568]])

# %%
Y_train
# Out:
# 6030    Yes
# 3410    Yes
# 5483    Yes
# 5524     No
# 6337     No
#        ...
# 3778     No
# 5199     No
# 5235     No
# 5399     No
# 862     Yes
# Name: Churn, Length: 5625, dtype: object

# %%
print(df["Churn"].unique())
# Out:
# ['No' 'Yes']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# model = LogisticRegression()
# model = DecisionTreeClassifier()
model = RandomForestClassifier()
model.fit(X_train,Y_train)
print(model.score(X_train,Y_train))
# Out:
# 0.9975111111111111

# %%
prediction = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(Y_test,prediction)*100
accuracy
# Out:
# 78.74911158493248

# %% [markdown]
# LogisticRegression accuracy = 78.67803837953092
# DecisionTreeClassifier = 71.92608386638237
#  RandomForestClassifier = 77.89623312011372

# %% [markdown]
# Hyper Tuning

# %%
# model= LogisticRegression(max_iter=500)
from sklearn.model_selection import GridSearchCV
# solvers = ['newton-cg','lbfgs','liblinear']
# penalty = ['l1','l2']
# c_values = [100, 10,0.1,0.001]
# parameters = dict(solver=solvers, penalty=penalty, C=c_values)

# grid_search_log = GridSearchCV(estimator= model,param_grid=parameters,cv =5)
# grid_search_log.fit(X_train, Y_train)
parameters ={'min_samples_split':range(10,500,20),'max_depth':range(1,20,2),'criterion':['gini','entropy']}
clf_tree = DecisionTreeClassifier()
# GreedSearch to find the best parameters for increasing results
clf = GridSearchCV(clf_tree,parameters,cv=5)
clf.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 20, 2),
#                          'min_samples_split': range(10, 500, 20)})

# %%
clf.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_split=110)

# %%
clf_predict  = clf.predict(X_test)

# %%
accuracy_score(clf_predict,Y_test)
# Out:
# 0.7569296375266524

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
print(knn.score(X_test, Y_test))
# Out:
# 0.7434257285003554

# %%
X_test
# Out:
# array([[ 0.99065797,  2.27103902,  1.03561683, ..., -1.47385696,
#         -1.32291009, -0.34481026],
#        [-1.00943013, -0.44032709, -0.9656081 , ..., -1.47385696,
#         -1.33288222, -0.80183635],
#        [ 0.99065797, -0.44032709,  1.03561683, ..., -0.53702589,
#          1.24491416, -0.40778977],
#        ...,
#        [-1.00943013, -0.44032709, -0.9656081 , ...,  1.33663626,
#         -0.29079432, -0.32211116],
#        [-1.00943013,  2.27103902, -0.9656081 , ..., -1.47385696,
#          1.52911996,  0.68516394],
#        [-1.00943013, -0.44032709,  1.03561683, ..., -1.47385696,
#         -1.31958604, -0.1877034 ]])

# %%
knnpre = knn.predict(X_test)

# %%
accuracy_score(Y_test,knnpre)*100
# Out:
# 74.34257285003554

# %%
k_range = range(1,26)
score = {}
score_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, Y_train)
    predictions = knn.predict(X_test)
    score[k] = accuracy_score(Y_test, predictions)
    score_list.append(accuracy_score(Y_test, predictions))

# %%
score
# Out:
# {1: 0.7142857142857143,
#  2: 0.7533759772565742,
#  3: 0.7370291400142146,
#  4: 0.7611940298507462,
#  5: 0.7434257285003554,
#  6: 0.7526652452025586,
#  7: 0.7562189054726368,
#  8: 0.7690120824449183,
#  9: 0.759772565742715,
#  10: 0.7725657427149965,
#  11: 0.7732764747690121,
#  12: 0.7732764747690121,
#  13: 0.7718550106609808,
#  14: 0.7711442786069652,
#  15: 0.7647476901208244,
#  16: 0.7704335465529495,
#  17: 0.7661691542288557,
#  18: 0.7704335465529495,
#  19: 0.7633262260127932,
#  20: 0.7704335465529495,
#  21: 0.7668798862828714,
#  22: 0.7739872068230277,
#  23: 0.7683013503909026,
#  24: 0.7718550106609808,
#  25: 0.7640369580668088}

# %%
from sklearn.ensemble import GradientBoostingClassifier

GB = GradientBoostingClassifier()
GB.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
GBpredict = GB.predict(X_test)

# %%
GB_accuracy = accuracy_score(Y_test,GBpredict)*100
GB_accuracy
# Out:
# 78.74911158493248

# %%
tuned_paramaters = {'n_estimators': [100, 200, 300,400,500],'learning_rate': [0.1, 0.05, 0.01]}
gb=GradientBoostingClassifier(random_state = 42)
tree_grid = GridSearchCV(estimator=gb, param_grid=tuned_paramaters, cv = 5)
gb_model_tuned = tree_grid.fit(X_train, Y_train)
print('Best parameters for gradient boosting classifier: ',gb_model_tuned.best_params_, '\n')
# Out:
# Best parameters for gradient boosting classifier:  {'learning_rate': 0.01, 'n_estimators': 400}

# %%
gb = GradientBoostingClassifier(n_estimators=400, learning_rate=0.01, random_state=42)
gb.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, n_estimators=400,
#                            random_state=42)

# %%
gbpredict = gb.predict(X_test)

# %%
gbAccuracy = accuracy_score(Y_test,gbpredict)*100
gbAccuracy
# Out:
# 79.38877043354655

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", confusion_matrix(Y_test,gbpredict))
print("\nClassification Report:\n", classification_report(Y_test,gbpredict))
# Out:
# Accuracy: 78.74911158493248
#
# Confusion Matrix:
#  [[941  92]
#  [198 176]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           No       0.83      0.91      0.87      1033
#          Yes       0.66      0.47      0.55       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.69      0.71      1407
# weighted avg       0.78      0.79      0.78      1407
